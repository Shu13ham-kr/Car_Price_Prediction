# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
data = pd.read_csv("CarPrice_Assignment.csv")

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#Detecting outliers1
sb.boxplot(data["price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
print(np.where(data["price"]>30000))
# Out:
# (array([ 15,  16,  17,  47,  48,  49,  70,  71,  72,  73,  74, 126, 127,
#        128, 129], dtype=int64),)

# %%
#Detecting outliers2
Q75 = np.percentile(data["price"], 75)
Q25 = np.percentile(data["price"], 25)
IQR = Q75 - Q25
upper_b = Q75 + 1.5*IQR
lower_b = Q25 - 1.5*IQR

# %%
#removing outliers
data = data[(data["price"]<upper_b) & (data["price"]>lower_b)]

# %%
sb.boxplot(data["price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data = data.drop(["car_ID", "CarName"], axis = 1)
data
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# ..         ...      ...        ...        ...          ...        ...
# 200         -1      gas        std       four        sedan        rwd
# 201         -1      gas      turbo       four        sedan        rwd
# 202         -1      gas        std       four        sedan        rwd
# 203         -1   diesel      turbo       four        sedan        rwd
# 204         -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %%
for i in data:
    print(data[i].value_counts())
# Out:
#  0    60
#  1    52
#  2    32
#  3    23
# -1    20
# -2     3
# Name: symboling, dtype: int64
# gas       171
# diesel     19
# Name: fueltype, dtype: int64
# std      154
# turbo     36
# Name: aspiration, dtype: int64
# four    108
# two      82
# Name: doornumber, dtype: int64
# sedan          87
# hatchback      69
# wagon          25
# hardtop         5
# convertible     4
# Name: carbody, dtype: int64
# fwd    120
# rwd     61
# 4wd      9
# Name: drivewheel, dtype: int64
# front    190
# Name: enginelocation, dtype: int64
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 97.3      7
# 96.3      6
# 99.1      6
# 100.4     6
# 98.8      6
# 98.4      6
# 107.9     6
# 104.3     6
# 102.4     5
# 93.1      5
# 97.2      5
# 109.1     5
# 95.9      5
# 101.2     4
# 97.0      4
# 114.2     4
# 95.3      4
# 105.8     3
# 99.8      2
# 110.0     2
# 104.5     2
# 91.3      2
# 104.9     2
# 88.6      2
# 86.6      2
# 102.9     2
# 96.1      2
# 103.3     2
# ...

# %%
data = data.drop("enginelocation", axis = 1)

# %%
data
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# ..         ...      ...        ...        ...          ...        ...
# 200         -1      gas        std       four        sedan        rwd
# 201         -1      gas      turbo       four        sedan        rwd
# 202         -1      gas        std       four        sedan        rwd
# 203         -1   diesel      turbo       four        sedan        rwd
# 204         -1      gas      turbo       four        sedan        rwd
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
data["fueltype"] = LE.fit_transform(data["fueltype"])

# %%
data
# Out:
#      symboling  fueltype aspiration doornumber      carbody drivewheel  \
# 0            3         1        std        two  convertible        rwd
# 1            3         1        std        two  convertible        rwd
# 2            1         1        std        two    hatchback        rwd
# 3            2         1        std       four        sedan        fwd
# 4            2         1        std       four        sedan        4wd
# ..         ...       ...        ...        ...          ...        ...
# 200         -1         1        std       four        sedan        rwd
# 201         -1         1      turbo       four        sedan        rwd
# 202         -1         1        std       four        sedan        rwd
# 203         -1         0      turbo       four        sedan        rwd
# 204         -1         1      turbo       four        sedan        rwd
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# ...

# %%
data["aspiration"] = LE.fit_transform(data["aspiration"])
data["doornumber"] = LE.fit_transform(data["doornumber"])
data["carbody"] = LE.fit_transform(data["carbody"])
data["drivewheel"] = LE.fit_transform(data["drivewheel"])

# %%
data
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# ...

# %%
data["fuelsystem"] = LE.fit_transform(data["fuelsystem"])

# %%
data
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# ...

# %%
for i in data:
    if type(data[i][0])==str:
        print(i)
# Out:
# enginetype
# cylindernumber

# %%
data["cylindernumber"] = LE.fit_transform(data["cylindernumber"])
data["enginetype"] = LE.fit_transform(data["enginetype"])
data
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize  fuelsystem  \
# ...

# %%
for i in data:
    if type(data[i][0])==str:
        print(i)

# %%
data.corr()
# Out:
#                   symboling  fueltype  aspiration  doornumber   carbody  \
# symboling          1.000000  0.184481   -0.045174    0.661596 -0.565359
# fueltype           0.184481  1.000000   -0.376051    0.184189 -0.141585
# aspiration        -0.045174 -0.376051    1.000000   -0.014557  0.041143
# doornumber         0.661596  0.184189   -0.014557    1.000000 -0.682370
# carbody           -0.565359 -0.141585    0.041143   -0.682370  1.000000
# drivewheel        -0.043679 -0.155435    0.102812    0.089398 -0.118039
# wheelbase         -0.510587 -0.349575    0.312240   -0.453853  0.423670
# carlength         -0.327519 -0.238406    0.288336   -0.423849  0.383484
# carwidth          -0.210088 -0.284405    0.399463   -0.252889  0.201200
# carheight         -0.542455 -0.283181    0.072783   -0.538644  0.590424
# curbweight        -0.221915 -0.279516    0.447257   -0.243715  0.214034
# enginetype         0.068573  0.122236   -0.121257    0.058048  0.006022
# ...

# %%
x = data.iloc[:,:22]
y = data.iloc[:,22:23]

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# <ipython-input-294-d56147f4b850>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# ExtraTreesRegressor()

# %%
FE=model.feature_importances_
FE
# Out:
# array([0.00625927, 0.00651128, 0.0138486 , 0.00267521, 0.0084082 ,
#        0.05819506, 0.07053694, 0.0331391 , 0.11893258, 0.01218944,
#        0.17346745, 0.0082038 , 0.01750812, 0.08472054, 0.06841078,
#        0.00784136, 0.01397208, 0.01096036, 0.08268181, 0.03108762,
#        0.05746202, 0.11298838])

# %%
data
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize  fuelsystem  \
# ...

# %%
extra=[]
for i in range(len(FE)):
    if (FE[i]<0.05):
        extra.append(i)
print(extra)
# Out:
# [0, 1, 2, 3, 4, 7, 9, 11, 12, 15, 16, 17, 19]

# %%
data = data.drop(data.columns[extra],axis=1)

# %%
data
# Out:
#      drivewheel  wheelbase  carwidth  curbweight  enginesize  fuelsystem  \
# 0             2       88.6      64.1        2548         130           5
# 1             2       88.6      64.1        2548         130           5
# 2             2       94.5      65.5        2823         152           5
# 3             1       99.8      66.2        2337         109           5
# 4             0       99.4      66.4        2824         136           5
# ..          ...        ...       ...         ...         ...         ...
# 200           2      109.1      68.9        2952         141           5
# 201           2      109.1      68.8        3049         141           5
# 202           2      109.1      68.9        3012         173           5
# 203           2      109.1      68.9        3217         145           3
# 204           2      109.1      68.9        3062         141           5
#
#      horsepower  citympg  highwaympg    price
# ...

# %%
sb.set(rc = {"figure.figsize":(15,8)})
sb.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
x_train = SC.fit_transform(x_train)
x_test = SC.fit_transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(x_train, y_train)
# Out:
# <ipython-input-303-404555e55b62>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(x_train, y_train)
# RandomForestRegressor(random_state=0)

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 7738.665     ,  8598.26      , 10025.68      , 17731.98167   ,
#         6086.415     , 15890.57334   ,  6025.17      ,  7653.49166667,
#         7890.22      , 19117.57334   , 13150.8825    , 18999.06501   ,
#        12142.41      ,  8161.07      , 15754.33      , 16321.61334   ,
#         8900.7       ,  6102.25      ,  5792.34      ,  7862.96      ,
#         9483.94      , 15960.33167   , 12901.6775    , 15752.89      ,
#         8201.46      ,  8723.3       , 23779.85      , 12144.92      ,
#         9798.09      ,  7909.94966667, 15347.22168667,  9383.47      ,
#        18121.26334   ,  6407.725     ,  5915.355     , 15957.69334   ,
#        13575.20667   ,  7491.25      ])

# %%
reg.score(x_train,y_train)
# Out:
# 0.9775429791949315

# %%
reg.score(x_test,y_test)
# Out:
# 0.8788644572798394

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
y_pred = lin_reg.predict(x_test)
print("Predictions of price for the multiple test values of x are:", y_pred)
# Out:
# Predictions of price for the multiple test values of x are: [[10329.80342633]
#  [ 8749.29961351]
#  [ 9759.72876546]
#  [18769.53479389]
#  [ 7561.65780278]
#  [13473.79530032]
#  [ 5072.69560667]
#  [ 8412.29724601]
#  [ 7184.19257551]
#  [16263.15017747]
#  [11782.30235116]
#  [18361.23828673]
#  [13311.49562975]
#  [ 9581.20310821]
#  [15994.97407917]
#  [15520.79031167]
#  [ 6095.31401154]
#  [ 7575.31647323]
#  [ 7498.04303057]
#  [ 8443.56895963]
#  [ 9646.17288349]
#  [16875.25951057]
#  [10280.82984698]
#  [15767.61859607]
#  [10006.6313884 ]
#  [10967.48478539]
#  [21108.9158135 ]
#  [12108.07923655]
#  [ 9442.74797503]
#  [ 8803.02581957]
#  [11020.55076463]
#  [ 8676.57473329]
#  [22851.44865782]
#  [ 6547.1818211 ]
#  [ 7531.37250105]
#  [13072.90126023]
#  [13059.80903416]
#  [ 8376.03557256]]

# %%
lin_reg.score(x_train,y_train)
# Out:
# 0.8237473634170143

# %%
lin_reg.score(x_test,y_test)
# Out:
# 0.7654491461468257

# %%
sb.set(rc = {"figure.figsize":(10,5)})
data.price.plot()
# Out:
# <AxesSubplot:>

# %%
plt.hist(data["price"])
# Out:
# (array([42., 51., 27., 18., 19., 20.,  4.,  4.,  3.,  2.]),
#  array([ 5118.,  7431.,  9744., 12057., 14370., 16683., 18996., 21309.,
#         23622., 25935., 28248.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["price"], bins =6)
# Out:
# (array([82., 43., 32., 22.,  7.,  4.]),
#  array([ 5118.,  8973., 12828., 16683., 20538., 24393., 28248.]),
#  <BarContainer object of 6 artists>)

# %%
plt.hist(data["price"], bins =[10000,15000,20000,25000,30000])
# Out:
# (array([41., 38.,  8.,  3.]),
#  array([10000, 15000, 20000, 25000, 30000]),
#  <BarContainer object of 4 artists>)

# %%
a = y_test.iloc[:,:].values

# %%
y_pred
# Out:
# array([[10329.80342633],
#        [ 8749.29961351],
#        [ 9759.72876546],
#        [18769.53479389],
#        [ 7561.65780278],
#        [13473.79530032],
#        [ 5072.69560667],
#        [ 8412.29724601],
#        [ 7184.19257551],
#        [16263.15017747],
#        [11782.30235116],
#        [18361.23828673],
#        [13311.49562975],
#        [ 9581.20310821],
#        [15994.97407917],
#        [15520.79031167],
#        [ 6095.31401154],
#        [ 7575.31647323],
#        [ 7498.04303057],
#        [ 8443.56895963],
#        [ 9646.17288349],
#        [16875.25951057],
#        [10280.82984698],
#        [15767.61859607],
#        [10006.6313884 ],
#        [10967.48478539],
#        [21108.9158135 ],
#        [12108.07923655],
#        [ 9442.74797503],
#        [ 8803.02581957],
#        [11020.55076463],
#        [ 8676.57473329],
#        [22851.44865782],
#        [ 6547.1818211 ],
#        [ 7531.37250105],
#        [13072.90126023],
#        [13059.80903416],
# ...

# %%
plt.plot(a, label = "true value")
plt.plot(y_pred, label = "pred value")
plt.legend()
plt.show()
